# %%
from pathlib import Path
import re

from bs4 import BeautifulSoup

bangumi_html = Path("bangumi.txt").read_text(encoding="utf-8")
soup = BeautifulSoup(bangumi_html, "html.parser")

id_name_mapping = {}
for subtitle in soup.select("div.item h2.subtitle"):
    anchor = subtitle.find("a", href=re.compile(r"^/character/\d+"))
    if not anchor:
        continue

    match = re.search(r"/character/(\d+)", anchor["href"])
    if not match:
        continue

    character_id = match.group(1)
    japanese_name = anchor.get_text(strip=True)

    chinese_span = subtitle.find("span", class_="tip")
    chinese_name = chinese_span.get_text(strip=True) if chinese_span else ""

    id_name_mapping[character_id] = {
        "ja": japanese_name,
        "zh": chinese_name,
    }

for character_id, names in id_name_mapping.items():
    zh_name = f" / {names['zh']}" if names["zh"] else ""
    print(f"{character_id}: {names['ja']}{zh_name}")
# Out:
# 187565: レッドディザイア / 红色梦想
# 50576: スペシャルウィーク / 特别周
# 50577: サイレンススズカ / 无声铃鹿
# 50578: トウカイテイオー / 东海帝王
# 50599: マルゼンスキー / 丸善斯基
# 50586: オグリキャップ / 小栗帽
# 50593: タイキシャトル / 大树快车
# 50600: メジロマックイーン / 目白麦昆
# 50592: シンボリルドルフ / 鲁道夫象征
# 68386: ライスシャワー / 米浴
# 50588: ゴールドシップ / 黄金船
# 50580: ウオッカ / 伏特加
# 50594: ダイワスカーレット / 大和赤骥
# 50587: グラスワンダー / 草上飞
# 50585: エルコンドルパサー / 神鹰
# 50584: エアグルーヴ / 气槽
# 68392: マヤノトップガン / 重炮
# 60561: スーパークリーク / 超级溪流
# 60529: メジロライアン / 目白赖恩
# 68383: アグネスタキオン / 爱丽速子
# 60522: ウイニングチケット / 胜利奖券
# 62513: サクラバクシンオー / 樱花进王
# 60527: ハルウララ / 春乌菈菈
# 60530: マチカネフクキタル / 待兼福来
# 68394: ナイスネイチャ / 优秀素质
# 68395: キングヘイロー / 帝王光辉
# 50595: テイエムオペラオー / 好歌剧
# 62509: ミホノブルボン / 美浦波旁
# 62512: ビワハヤヒデ / 琵琶晨光
# 68388: カレンチャン / 真机伶
# 60558: ナリタタイシン / 成田大进
# 60557: スマートファルコン / 醒目飞鹰
# 50596: ナリタブライアン / 成田白仁
# 23243: セイウンスカイ / 青云天空
# 50597: ヒシアマゾン / 菱亚马逊
# 50598: フジキセキ / 富士奇石
# 60560: ゴールドシチー / 黄金城市
# 68385: メイショウドトウ / 名将怒涛
# 68390: エイシンフラッシュ / 荣进闪耀
# 62506: ヒシアケボノ / 菱曙
# 68389: アグネスデジタル / 爱丽数码
# 60528: カワカミプリンセス / 川上公主
# 60525: マンハッタンカフェ / 曼城茶座
# 60526: トーセンジョーダン / 东瀛佐敦
# 68393: メジロドーベル / 目白多伯
# 60556: ファインモーション / 美妙姿势
# 60523: タマモクロス / 玉藻十字
# 96119: サクラチヨノオー / 樱花千代王
# 106681: メジロアルダン / 目白阿尔丹
# 68387: アドマイヤベガ / 爱慕织姬
# 89568: キタサンブラック / 北部玄驹
# 90095: マチカネタンホイザ / 待兼诗歌剧
# 89569: サトノダイヤモンド / 里见光钻
# 106373: メジロブライト / 目白光明
# 62504: ニシノフラワー / 西野花
# 106374: ヤエノムテキ / 八重无敌
# 62511: アイネスフウジン / 艾尼风神
# 91246: メジロパーマー / 目白善信
# 60562: イナリワン / 稻荷一
# 62510: スイープトウショウ / 东商变革
# 60559: エアシャカール / 空中神宫
# 62507: バンブーメモリー / 青竹回忆
# 114176: コパノリッキー / 小林历奇
# 60524: シーキングザパール / 采珠
# 60521: ユキノビジン / 雪中美人
# 115274: アストンマーチャン / 真弓快车
# 109439: ヤマニンゼファー / 也文摄辉
# 68391: ナカヤマフェスタ / 中山庆典
# 114172: ワンダーアキュート / 奇锐骏
# 68384: ゼンノロブロイ / 荒漠英雄
# 114171: ホッコータルマエ / 北港火山
# 90096: ダイタクヘリオス / 大拓太阳神
# 68382: シンコウウインディ / 新光风
# 91610: ミスターシービー / CB先生
# 90090: ツインターボ / 双涡轮
# 107336: サクラローレル / 樱花桂冠
# 110329: シンボリクリスエス / 吉兆
# 133649: ネオユニヴァース / 新宇宙
# 133650: ヒシミラクル / 菱钻奇宝
# 115289: ダイイチルビー / 第一红宝
# 110330: タニノギムレット / 谷水琴蕾
# 62508: マーベラスサンデー / 美丽周日
# 125977: カツラギエース / 葛城王牌
# 106375: シリウスシンボリ / 天狼星象征
# 106372: ナリタトップロード / 成田路
# 115290: ケイエスミラクル / 凯斯奇迹
# 125975: メジロラモーヌ / 目白高峰
# 133651: タップダンスシチー / 跳舞城
# 122526: サトノクラウン / 里见皇冠
# 122525: シュヴァルグラン / 高尚骏逸
# 143489: ヴィブロス / 强击
# 62505: ビコーペガサス / 微光飞驹
# 139048: ドゥラメンテ / 大鸣大放
# 90093: イクノディクタス / 生野狄杜斯
# 152825: トランセンド / 创昇
# 152172: ラインクラフト / 莱茵力量
# 136229: サウンズオブアース / 万籁争鸣
# 138303: ノースフライト / 北方飞翔
# 125976: ジャングルポケット / 森林宝穴
# 160762: ドリームジャーニー / 梦之旅
# 160765: カルストンライトオ / 金镇之光
# 152831: ジェンティルドンナ / 贵妇人
# 152173: シーザリオ / 西沙里奥
# 160766: デュランダル / 多旺达
# 163803: バブルガムフェロー / 吹波糖
# 152174: エアメサイア / 空中救主
# 152832: ウインバリアシオン / 凯旋芭蕾
# 152824: フリオーソ / 狂怒乐章
# 108091: ツルマルツヨシ / 鹤丸刚志
# 152830: オルフェーヴル / 黄金巨匠
# 171891: グランアレグリア / 放声欢呼
# 152828: ノーリーズン / 莫名其妙
# 171889: フェノーメノ / 超常骏骥
# 143488: ヴィルシーナ / 极峰
# 171892: ラヴズオンリーユー / 唯独爱你
# 171894: クロノジェネシス / 创世驹
# 165057: フサイチパンドラ / 火神
# 152829: スティルインラブ / 爱如往昔
# 152826: エスポワールシチー / 希望之城
# 160764: ビリーヴ / 信念
# 125974: デアリングタクト / 谋勇兼备
# 143729: サムソンビッグ / 大森逊
# 148814: ロイスアンドロイス / 莱斯莱斯
# 152175: デアリングハート / 勇敢之心
# 152827: ダンツフレーム / 烈焰快驹
# 160763: ブエナビスタ / 迷人景致
# 168967: サクラチトセオー / 樱花千岁王
# 168970: ブラストワンピース / 防爆装束
# 171886: アーモンドアイ / 杏目
# 171890: ラッキーライラック / 旺紫丁
# 171896: カレンブーケドール / 机伶金花
# 176528: ステイゴールド / 黄金旅程
# 182695: アドマイヤグルーヴ / 爱慕律动
# 91544: ハッピーミーク / 快乐米可
# 106377: ビターグラッセ / 微苦糖渍
# 106376: リトルココン / 小巧圆茧
# 136345: モンジュー / 望族
# 136337: ヴェニュスパーク / 金星复活节
# 136338: リガントーナ / 伟大女王
# 152833: ソノンエルフィー
# 166375: シュガーライツ
# 171899: セントライト / 圣列特
# 171902: スピードシンボリ / 速度象征
# 171903: ハイセイコー / 海塞克
# 61482: 駿川たづな / 骏川手纲
# 94764: 秋川やよい / 秋川弥生
# 106378: 乙名史悦子 / 乙名史悦子
# 97095: 桐生院葵 / 桐生院葵
# 106380: 安心沢刺々美 / 安心泽刺刺美
# 106379: 樫本理子 / 㭴本理子
# 115291: ライトハロー / 明亮光晕
# 178383: タッカーブライン
# 125978: ダーレーアラビアン / 达利阿拉伯
# 125979: ゴドルフィンバルブ / 高多芬柏布
# 125980: バイアリーターク / 拜耶尔土耳其
# 136336: 佐岳メイ / 佐岳鸣
# 152834: 都留岐涼花 / 都留岐凉花
# 68589: 赤坂美聡 / 赤坂美聪
# 68590: 細江純子 / 细江纯子

# %%
from collections import defaultdict

bwiki_html = Path("bwiki.txt").read_text(encoding="utf-8")
bwiki_soup = BeautifulSoup(bwiki_html, "html.parser")

columns = [
    "稀有度",
    "草地",
    "泥地",
    "短距离",
    "英里",
    "中距离",
    "长距离",
    "领跑",
    "跟前",
    "居中",
    "后追",
]

ja_to_ids = defaultdict(list)
for character_id, names in id_name_mapping.items():
    ja_to_ids[names["ja"]].append(character_id)

def make_stat_dict():
    return {column: [] for column in columns}

character_stats = defaultdict(make_stat_dict)

grade_letter_pattern = re.compile(r"[SABCDEFUG]")


def extract_grade(cell):
    hidden = cell.find("div")
    if hidden:
        hidden_text = hidden.get_text(strip=True)
        if hidden_text:
            return hidden_text

    for img in cell.find_all("img", alt=True):
        match = grade_letter_pattern.search(img["alt"])
        if match:
            return match.group(0)

    text = cell.get_text(separator=" ", strip=True)
    match = grade_letter_pattern.search(text)
    if match:
        return match.group(0)

    return None


def extract_initial_stars(cell):
    star_imgs = cell.find_all("img")
    if star_imgs:
        return len(star_imgs)

    digits = re.findall(r"\d+", cell.get_text())
    return int(digits[0]) if digits else None


column_indices = {
    "稀有度": 2,
    "草地": 8,
    "泥地": 9,
    "短距离": 10,
    "英里": 11,
    "中距离": 12,
    "长距离": 13,
    "领跑": 14,
    "跟前": 15,
    "居中": 16,
    "后追": 17,
}

for row in bwiki_soup.select("table#CardSelectTr tbody tr"):
    cells = row.find_all("td")
    if len(cells) <= max(column_indices.values()):
        continue

    name_cell = cells[1]
    ja_name = None
    for span in name_cell.find_all("span", attrs={"lang": "ja"}):
        text = span.get_text(strip=True)
        if not text:
            continue
        if text.startswith("【") and text.endswith("】"):
            continue
        ja_name = text
        break

    if not ja_name:
        anchors = name_cell.find_all("a")
        for anchor in anchors:
            text = anchor.get_text(strip=True)
            if text:
                ja_name = text
                break

    if not ja_name:
        continue

    target_ids = ja_to_ids.get(ja_name)
    if not target_ids:
        continue

    for column, index in column_indices.items():
        value = (
            extract_initial_stars(cells[index])
            if column == "稀有度"
            else extract_grade(cells[index])
        )
        if value is None or value == "":
            continue

        for character_id in target_ids:
            current_values = character_stats[character_id][column]
            if value not in current_values:
                current_values.append(value)

for character_id in sorted(character_stats.keys(), key=int):
    names = id_name_mapping[character_id]
    print(f"{character_id}: {names['ja']} / {names['zh']}")
    for column in columns:
        values = character_stats[character_id][column]
        if values:
            print(f"  {column}: {values}")
# Out:
# 23243: セイウンスカイ / 青云天空
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['A']
#   跟前: ['B']
#   居中: ['D']
#   后追: ['E']
# 50576: スペシャルウィーク / 特别周
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 50577: サイレンススズカ / 无声铃鹿
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['A']
#   跟前: ['C']
#   居中: ['E']
#   后追: ['G']
# 50578: トウカイテイオー / 东海帝王
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['B', 'A']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['E']
# 50580: ウオッカ / 伏特加
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['F', 'E']
#   领跑: ['C']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['F']
# 50584: エアグルーヴ / 气槽
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['C']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['G']
# 50585: エルコンドルパサー / 神鹰
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['B']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 50586: オグリキャップ / 小栗帽
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['B']
#   短距离: ['E']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 50587: グラスワンダー / 草上飞
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A', 'B']
#   中距离: ['B', 'A']
#   长距离: ['A']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['F']
# 50588: ゴールドシップ / 黄金船
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['B']
#   后追: ['A']
# 50592: シンボリルドルフ / 鲁道夫象征
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 50593: タイキシャトル / 大树快车
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['B']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['E']
#   长距离: ['G']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 50594: ダイワスカーレット / 大和赤骥
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['A', 'B']
#   中距离: ['A']
#   长距离: ['B', 'A']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 50595: テイエムオペラオー / 好歌剧
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['G']
# 50596: ナリタブライアン / 成田白仁
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 50597: ヒシアマゾン / 菱亚马逊
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['C']
#   后追: ['A']
# 50598: フジキセキ / 富士奇石
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['E']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 50599: マルゼンスキー / 丸善斯基
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['D']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['C']
#   领跑: ['A']
#   跟前: ['E']
#   居中: ['G']
#   后追: ['G']
# 50600: メジロマックイーン / 目白麦昆
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['D']
#   后追: ['F']
# 60521: ユキノビジン / 雪中美人
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['B', 'A']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['F']
#   后追: ['G']
# 60522: ウイニングチケット / 胜利奖券
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['G']
# 60523: タマモクロス / 玉藻十字
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['A']
# 60524: シーキングザパール / 采珠
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['E']
#   长距离: ['G']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['B']
# 60525: マンハッタンカフェ / 曼城茶座
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['B']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['C']
#   居中: ['A']
#   后追: ['C', 'A']
# 60526: トーセンジョーダン / 东瀛佐敦
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['B', 'A']
#   后追: ['G']
# 60527: ハルウララ / 春乌菈菈
#   稀有度: [1, 3]
#   草地: ['G']
#   泥地: ['A']
#   短距离: ['A']
#   英里: ['B', 'A']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['G']
#   居中: ['A']
#   后追: ['B']
# 60528: カワカミプリンセス / 川上公主
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['D']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['G']
#   跟前: ['C']
#   居中: ['A']
#   后追: ['D']
# 60529: メジロライアン / 目白赖恩
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['F']
# 60530: マチカネフクキタル / 待兼福来
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['F']
# 60556: ファインモーション / 美妙姿势
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['C']
# 60557: スマートファルコン / 醒目飞鹰
#   稀有度: [3]
#   草地: ['E']
#   泥地: ['A']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['A']
#   跟前: ['D']
#   居中: ['G']
#   后追: ['G']
# 60558: ナリタタイシン / 成田大进
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['D']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['F']
#   居中: ['B']
#   后追: ['A']
# 60559: エアシャカール / 空中神宫
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['C']
#   居中: ['A']
#   后追: ['A']
# 60560: ゴールドシチー / 黄金城市
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['D']
#   短距离: ['F']
#   英里: ['A', 'B']
#   中距离: ['B', 'A']
#   长距离: ['B', 'A']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['F']
# 60561: スーパークリーク / 超级溪流
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['G']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['G']
# 60562: イナリワン / 稻荷一
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['A']
#   短距离: ['F']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['B']
#   后追: ['A']
# 62504: ニシノフラワー / 西野花
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['E']
#   长距离: ['G']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['G']
# 62505: ビコーペガサス / 微光飞驹
#   稀有度: [2]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['A']
#   英里: ['B']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['E']
#   居中: ['A']
#   后追: ['B']
# 62506: ヒシアケボノ / 菱曙
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['A']
#   英里: ['B']
#   中距离: ['F']
#   长距离: ['G']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 62507: バンブーメモリー / 青竹回忆
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['D']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['C']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['E']
#   居中: ['A']
#   后追: ['C']
# 62508: マーベラスサンデー / 美丽周日
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 62509: ミホノブルボン / 美浦波旁
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['C']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['A']
#   跟前: ['E']
#   居中: ['G']
#   后追: ['G']
# 62510: スイープトウショウ / 东商变革
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['D']
#   领跑: ['G']
#   跟前: ['G']
#   居中: ['A']
#   后追: ['A']
# 62511: アイネスフウジン / 艾尼风神
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['A']
#   跟前: ['C']
#   居中: ['G']
#   后追: ['G']
# 62512: ビワハヤヒデ / 琵琶晨光
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['E']
# 62513: サクラバクシンオー / 樱花进王
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['B']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['F']
#   后追: ['G']
# 68382: シンコウウインディ / 新光风
#   稀有度: [3]
#   草地: ['F']
#   泥地: ['A']
#   短距离: ['C']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['F']
# 68383: アグネスタキオン / 爱丽速子
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['D']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['F']
# 68384: ゼンノロブロイ / 荒漠英雄
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['E']
# 68385: メイショウドトウ / 名将怒涛
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['E']
# 68386: ライスシャワー / 米浴
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 68387: アドマイヤベガ / 爱慕织姬
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['G']
#   居中: ['B']
#   后追: ['A']
# 68388: カレンチャン / 真机伶
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['A']
#   英里: ['D']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 68389: アグネスデジタル / 爱丽数码
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['A']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['B']
# 68390: エイシンフラッシュ / 荣进闪耀
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['C']
# 68391: ナカヤマフェスタ / 中山庆典
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 68392: マヤノトップガン / 重炮
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['D']
#   英里: ['D']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['B']
# 68393: メジロドーベル / 目白多伯
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['C']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['G']
# 68394: ナイスネイチャ / 优秀素质
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['F']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['D']
# 68395: キングヘイロー / 帝王光辉
#   稀有度: [1, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['B', 'A']
#   中距离: ['B']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['D']
# 89568: キタサンブラック / 北部玄驹
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['A']
#   跟前: ['B']
#   居中: ['C']
#   后追: ['G']
# 89569: サトノダイヤモンド / 里见光钻
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['D']
# 90090: ツインターボ / 双涡轮
#   稀有度: [1]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['A']
#   跟前: ['G']
#   居中: ['G']
#   后追: ['G']
# 90093: イクノディクタス / 生野狄杜斯
#   稀有度: [2]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['D']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 90095: マチカネタンホイザ / 待兼诗歌剧
#   稀有度: [2, 3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['D']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['E']
# 90096: ダイタクヘリオス / 大拓太阳神
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['E']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['G']
#   后追: ['G']
# 91246: メジロパーマー / 目白善信
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['A']
#   跟前: ['E']
#   居中: ['F']
#   后追: ['G']
# 91610: ミスターシービー / CB先生
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['E']
#   居中: ['A']
#   后追: ['A']
# 96119: サクラチヨノオー / 樱花千代王
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['F']
#   后追: ['G']
# 106372: ナリタトップロード / 成田路
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['D']
# 106373: メジロブライト / 目白光明
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['D']
#   居中: ['A']
#   后追: ['A']
# 106374: ヤエノムテキ / 八重无敌
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['G']
# 106375: シリウスシンボリ / 天狼星象征
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['C', 'A']
#   后追: ['E']
# 106681: メジロアルダン / 目白阿尔丹
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['E']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['D']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['D']
#   后追: ['G']
# 107336: サクラローレル / 樱花桂冠
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['B']
# 108091: ツルマルツヨシ / 鹤丸刚志
#   稀有度: [2]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['F']
#   英里: ['D']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['E']
# 109439: ヤマニンゼファー / 也文摄辉
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['D']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 110329: シンボリクリスエス / 吉兆
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 110330: タニノギムレット / 谷水琴蕾
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['G']
#   跟前: ['D']
#   居中: ['A']
#   后追: ['A']
# 114171: ホッコータルマエ / 北港火山
#   稀有度: [3]
#   草地: ['G']
#   泥地: ['A']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['B']
#   跟前: ['A']
#   居中: ['G']
#   后追: ['G']
# 114172: ワンダーアキュート / 奇锐骏
#   稀有度: [3]
#   草地: ['G']
#   泥地: ['A']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['C', 'B']
#   后追: ['E']
# 114176: コパノリッキー / 小林历奇
#   稀有度: [3]
#   草地: ['F']
#   泥地: ['A']
#   短距离: ['C']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 115274: アストンマーチャン / 真弓快车
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['B']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['G']
#   后追: ['G']
# 115289: ダイイチルビー / 第一红宝
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['C']
#   长距离: ['G']
#   领跑: ['E']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['A']
# 115290: ケイエスミラクル / 凯斯奇迹
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['B']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['C']
# 122525: シュヴァルグラン / 高尚骏逸
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['G']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['F']
# 122526: サトノクラウン / 里见皇冠
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['D']
# 125975: メジロラモーヌ / 目白高峰
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['B']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['E']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['F']
# 125976: ジャングルポケット / 森林宝穴
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['G']
#   跟前: ['D']
#   居中: ['A']
#   后追: ['B']
# 125977: カツラギエース / 葛城王牌
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 133649: ネオユニヴァース / 新宇宙
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['B']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 133650: ヒシミラクル / 菱钻奇宝
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['G']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['C']
#   居中: ['A']
#   后追: ['B']
# 133651: タップダンスシチー / 跳舞城
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['A']
#   跟前: ['B']
#   居中: ['F']
#   后追: ['G']
# 136229: サウンズオブアース / 万籁争鸣
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['F']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['E']
# 138303: ノースフライト / 北方飞翔
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['C']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['G']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['D']
#   后追: ['C']
# 139048: ドゥラメンテ / 大鸣大放
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['C']
#   居中: ['A']
#   后追: ['A']
# 143488: ヴィルシーナ / 极峰
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['D']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 143489: ヴィブロス / 强击
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['E']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['D']
#   居中: ['A']
#   后追: ['C']
# 152172: ラインクラフト / 莱茵力量
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A', 'B']
#   英里: ['A']
#   中距离: ['B', 'A']
#   长距离: ['G']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['G']
# 152173: シーザリオ / 西沙里奥
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['C']
# 152174: エアメサイア / 空中救主
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['C']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['E']
# 152824: フリオーソ / 狂怒乐章
#   稀有度: [3]
#   草地: ['G']
#   泥地: ['A']
#   短距离: ['F']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 152825: トランセンド / 创昇
#   稀有度: [3]
#   草地: ['F']
#   泥地: ['A']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['B']
#   居中: ['F']
#   后追: ['G']
# 152826: エスポワールシチー / 希望之城
#   稀有度: [3]
#   草地: ['E']
#   泥地: ['A']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['B']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['A']
#   居中: ['F']
#   后追: ['G']
# 152827: ダンツフレーム / 烈焰快驹
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['E']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['D']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['D']
# 152828: ノーリーズン / 莫名其妙
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['D']
#   居中: ['A']
#   后追: ['F']
# 152829: スティルインラブ / 爱如往昔
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['C']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['F']
# 152830: オルフェーヴル / 黄金巨匠
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['D']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['F']
#   居中: ['A']
#   后追: ['A']
# 152831: ジェンティルドンナ / 贵妇人
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['D']
# 152832: ウインバリアシオン / 凯旋芭蕾
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['E']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['E']
#   居中: ['A']
#   后追: ['A']
# 160762: ドリームジャーニー / 梦之旅
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['F']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['G']
#   居中: ['A']
#   后追: ['A']
# 160763: ブエナビスタ / 迷人景致
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['F']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['C']
#   领跑: ['G']
#   跟前: ['B']
#   居中: ['A']
#   后追: ['A']
# 160764: ビリーヴ / 信念
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['D']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['D']
#   跟前: ['A']
#   居中: ['D']
#   后追: ['G']
# 160765: カルストンライトオ / 金镇之光
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['D']
#   中距离: ['G']
#   长距离: ['G']
#   领跑: ['A']
#   跟前: ['C']
#   居中: ['G']
#   后追: ['G']
# 160766: デュランダル / 多旺达
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['F']
#   长距离: ['G']
#   领跑: ['G']
#   跟前: ['G']
#   居中: ['C']
#   后追: ['A']
# 163803: バブルガムフェロー / 吹波糖
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['A']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['E']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['G']
# 165057: フサイチパンドラ / 火神
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['E']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['G']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['B']
#   后追: ['F']
# 171889: フェノーメノ / 超常骏骥
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['G']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['C']
#   跟前: ['A']
#   居中: ['E']
#   后追: ['G']
# 171891: グランアレグリア / 放声欢呼
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['A']
#   英里: ['A']
#   中距离: ['C']
#   长距离: ['G']
#   领跑: ['F']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['B']
# 171892: ラヴズオンリーユー / 唯独爱你
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['C']
#   中距离: ['A']
#   长距离: ['F']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['A']
#   后追: ['G']
# 171894: クロノジェネシス / 创世驹
#   稀有度: [3]
#   草地: ['A']
#   泥地: ['G']
#   短距离: ['G']
#   英里: ['B']
#   中距离: ['A']
#   长距离: ['A']
#   领跑: ['G']
#   跟前: ['A']
#   居中: ['C']
#   后追: ['E']

# %%
import json

output_path = Path("../../outputs/extra_tags/175552.json")

terrain_columns = ["草地", "泥地"]
distance_columns = ["短距离", "英里", "中距离", "长距离"]
running_style_columns = ["领跑", "跟前", "居中", "后追"]

def should_add_tag(values):
    return any(value in {"A", "B"} for value in values)

tags = {}
for character_id in sorted(character_stats.keys(), key=int):
    stats = character_stats[character_id]
    entry = {}
    entry["_name"] = id_name_mapping[character_id]["zh"]

    rarity_values = sorted({value for value in stats["稀有度"] if isinstance(value, int)})
    if rarity_values:
        entry["稀有度"] = {
            f"{rarity}星": f"<img src='/assets/tag/umamusume/{rarity}star.png' alt='{rarity}星' />"
            for rarity in rarity_values
        }

    terrain_tags = {
        column: column
        for column in terrain_columns
        if should_add_tag(stats[column])
    }
    if terrain_tags:
        entry["场地"] = terrain_tags

    distance_tags = {
        column: column
        for column in distance_columns
        if should_add_tag(stats[column])
    }
    if distance_tags:
        entry["距离"] = distance_tags

    running_tags = {
        column: column
        for column in running_style_columns
        if should_add_tag(stats[column])
    }
    if running_tags:
        entry["跑法"] = running_tags

    if entry:
        tags[character_id] = entry

output_path.write_text(json.dumps(tags, ensure_ascii=False, indent=2), encoding="utf-8")
print(f"Wrote {len(tags)} entries to {output_path}")
# Out:
# Wrote 121 entries to 175552.json
